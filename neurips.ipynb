# %%
import numpy as np
import os
import matplotlib.pyplot as plt
from matplotlib import rc
rc('text', usetex=True)

# %% [markdown]
# # 1) dataset : mini

# %% [markdown]
# ## arch : Resnet 18

# %%
list_shots = [5, 10, 20]
list_methods = ['KM-UNBIASED', 'KM-BIASED', 'TIM-GD', 'ALPHA-TIM', 'LaplacianShot', 'Baseline','BDCSPN', 'PT-MAP']
list_name = ['Ours', 'K-Means', 'TIM-GD', r'$\alpha$-TIM', 'Laplacian Shot', 'Baseline', 'BDCSPN', 'PT-MAP']
dataset = 'mini'
arch = 'resnet18'
folder = './results_test/' + dataset + '/' + arch + '/'

plt.figure(figsize=(24,6))
for i, shot in enumerate(list_shots):
    plt.subplot(1, 3, i+1)
    plt.axis([1.7, 8, 0, 100])
    for j, method in enumerate(list_methods):
        file_path = folder + method + '_alpha1_shots{}.txt'.format(shot)
        tab = np.genfromtxt(file_path, dtype=float, delimiter='\t')

        list_classes = tab[:, 0]
        list_acc = tab[:, 1]
        plt.plot(list_classes, list_acc, 'o-',label=list_name[j])
    plt.xlabel('Number of classes')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.title('Number of shots: {}'.format(shot))
plt.show()

# %% [markdown]
# ## arch : wideres

# %%
list_shots = [5, 10, 20]
list_methods = ['KM-UNBIASED', 'KM-BIASED', 'TIM-GD', 'ALPHA-TIM', 'LaplacianShot', 'Baseline','BDCSPN', 'PT-MAP']
list_name = ['Ours', 'K-Means', 'TIM-GD', r'$\alpha$-TIM', 'Laplacian Shot', 'Baseline', 'BDCSPN', 'PT-MAP']
dataset = 'mini'
arch = 'wideres'
folder = './results_test/' + dataset + '/' + arch + '/'

plt.figure(figsize=(24,6))
for i, shot in enumerate(list_shots):
    plt.subplot(1, 3, i+1)
    plt.axis([1.7, 8, 0, 100])
    for j, method in enumerate(list_methods):
        file_path = folder + method + '_alpha1_shots{}.txt'.format(shot)
        tab = np.genfromtxt(file_path, dtype=float, delimiter='\t')

        list_classes = tab[:, 0]
        list_acc = tab[:, 1]
        plt.plot(list_classes, list_acc, 'o-',label=list_name[j])
    plt.xlabel('Number of classes')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.title('Number of shots: {}'.format(shot))
plt.show()

# %% [markdown]
# # 2) dataset : tiered

# %% [markdown]
# ## arch : Resnet 18

# %%
list_shots = [5, 10, 20]
list_methods = ['KM-UNBIASED', 'KM-BIASED', 'TIM-GD', 'ALPHA-TIM', 'LaplacianShot', 'Baseline','BDCSPN']
list_name = ['Ours', 'K-Means', 'TIM-GD', r'$\alpha$-TIM', 'Laplacian Shot', 'Baseline','BDCSPN']
dataset = 'tiered'
arch = 'resnet18'
folder = './results_test/' + dataset + '/' + arch + '/'

plt.figure(figsize=(24,6))
for i, shot in enumerate(list_shots):
    plt.subplot(1, 3, i+1)
    plt.axis([1.7, 10.2, 0, 100])
    for j, method in enumerate(list_methods):
        file_path = folder + method + '_alpha1_shots{}.txt'.format(shot)
        tab = np.genfromtxt(file_path, dtype=float, delimiter='\t')

        list_classes = tab[:, 0]
        list_acc = tab[:, 1]
        plt.plot(list_classes, list_acc, 'o-',label=list_name[j])
    plt.xlabel('Number of classes')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.title('Number of shots: {}'.format(shot))
plt.show()

# %% [markdown]
# ## arch : wideres

# %%
list_shots = [5, 10, 20]
list_methods = ['KM-UNBIASED', 'KM-BIASED', 'TIM-GD', 'ALPHA-TIM', 'LaplacianShot', 'Baseline','BDCSPN']
list_name = ['Ours', 'K-Means', 'TIM-GD', r'$\alpha$-TIM', 'Laplacian Shot', 'Baseline','BDCSPN']
dataset = 'tiered'
arch = 'wideres'
folder = './results_test/' + dataset + '/' + arch + '/'

plt.figure(figsize=(24,6))
for i, shot in enumerate(list_shots):
    plt.subplot(1, 3, i+1)
    plt.axis([1.7, 10.2, 0, 100])
    for j, method in enumerate(list_methods):
        file_path = folder + method + '_alpha1_shots{}.txt'.format(shot)
        tab = np.genfromtxt(file_path, dtype=float, delimiter='\t')

        list_classes = tab[:, 0]
        list_acc = tab[:, 1]
        plt.plot(list_classes, list_acc, 'o-',label=list_name[j])
    plt.xlabel('Number of classes')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.title('Number of shots: {}'.format(shot))
plt.show()
